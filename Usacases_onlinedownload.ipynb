# %%
from pandas.io.html import read_html
import pandas as pd
page='https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_the_United_States#covid19-container'
tables=read_html(page, attrs={'class':'wikitable'})

# %%
tables[0]
# Out:
#    [show all]vte2020 coronavirus pandemic in the United States by state and territory  \
#                                                            U.S. state or territory[i]
#                                                                               55 / 56
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# ...

# %%
tables[0].drop(tables[0].index[56],inplace=True)

# %%
tables[0]
# Out:
#    [show all]vte2020 coronavirus pandemic in the United States by state and territory  \
#                                                            U.S. state or territory[i]
#                                                                               55 / 56
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# ...

# %%
tables[0].drop(tables[0].index[56],inplace=True)

# %%
tables[0]
# Out:
#    [show all]vte2020 coronavirus pandemic in the United States by state and territory  \
#                                                            U.S. state or territory[i]
#                                                                               55 / 56
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# ...

# %%
for col in tables[0].columns:
    print(col)
# Out:
# ('[show all]vte2020 coronavirus pandemic in the United States by state and territory', 'U.S. state or territory[i]', '55 / 56')
# ('[show all]vte2020 coronavirus pandemic in the United States by state and territory', 'U.S. state or territory[i]', '55 / 56.1')
# ('[show all]vte2020 coronavirus pandemic in the United States by state and territory', 'Cases[ii]', '549,329')
# ('[show all]vte2020 coronavirus pandemic in the United States by state and territory', 'Deaths', '21,794')
# ('[show all]vte2020 coronavirus pandemic in the United States by state and territory', 'Recov.[iii]', '34,798')
# ('[show all]vte2020 coronavirus pandemic in the United States by state and territory', 'Hospital[iv]', '86,404')
# ('[show all]vte2020 coronavirus pandemic in the United States by state and territory', 'Ref.', '[26]')
# ('Unnamed: 7_level_0', 'Unnamed: 7_level_1', 'Unnamed: 7_level_2')

# %%
tables[0].drop(tables[0].index[0],inplace=True)

# %%
tables[0]
# Out:
#    [show all]vte2020 coronavirus pandemic in the United States by state and territory  \
#                                                            U.S. state or territory[i]
#                                                                               55 / 56
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# ...
